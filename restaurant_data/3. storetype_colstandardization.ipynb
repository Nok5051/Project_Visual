# %%
import pandas as pd

# %%
df = pd.read_csv('C:/worksplaces/workspace_project/project_visual/restaurant_data/data/menu.csv')

# %%
df['storetype'].unique()
# Out:
# array(['한식', '테이크아웃커피', '카페', '우동,소바', '백반,가정식', '푸드코트', '두부요리', '베이커리',
#        '생선회', '요리주점', '프랑스음식', '국수', '맥주,호프', '사철,영양탕', '칼국수,만두', '쌈밥',
#        '한정식', '김밥', '종합분식', '카페,디저트', '호떡', '돈가스', '양식', '소고기구이', '포장마차',
#        '육류,고기요리', '해물,생선요리', '돼지고기구이', '복어요리', '차', '이자카야', '이탈리아음식',
#        '중식당', '바(BAR)', '뷔페', '멕시코,남미음식', '곱창,막창,양', '순대,순댓국', '베트남음식',
#        '전통,민속주점', '정육식당', '조개요리', '장어,먹장어요리', '족발,보쌈', '떡볶이', '치킨,닭강정',
#        '와인', '닭요리', '오리요리', '일식당', '냉면', '곰탕,설렁탕', '찌개,전골', '생선구이', '분식',
#        '닭갈비', '샌드위치', '스파게티,파스타전문', '감자탕', '초밥,롤', '만두', '빙수', '샤브샤브',
#        '바닷가재요리', '퓨전음식', '양꼬치', '주꾸미요리', '전,빈대떡', '백숙,삼계탕', '해장국',
#        '다이어트,샐러드', '브런치', '닭볶음탕', '아귀찜,해물찜', '낙지요리', '추어탕', '오뎅,꼬치',
#        '스페인음식', '케이크전문', '피자', '국밥', '인도음식', '갤러리카페', '아이스크림', '향토음식',
#        '닭발', '플라워카페', '비빔밥', '카레', '매운탕,해물탕', '보리밥', '햄버거', '사찰음식', '찜닭',
#        '라면', '술집', '죽', '스테이크,립', '한방카페', '도시락,컵밥', '라이브카페', '홍차전문점',
# ...

# %% [markdown]
# ### 변환과정

# %% [markdown]
# 한식, 양식, 일식, 중식, 퓨전, 주류, 카페/디저트, 해산물, 기타

# %%
df['storetype'].replace('백반,가정식', '한식', inplace = True)
df['storetype'].replace('테이크아웃커피', '카페/디저트', inplace = True)
df['storetype'].replace('우동,소바', '일식', inplace = True)
df['storetype'].replace('카페', '카페/디저트', inplace = True)
df['storetype'].replace('푸드코트', '퓨전', inplace = True)
df['storetype'].replace('두부요리', '한식', inplace = True)
df['storetype'].replace('베이커리', '카페/디저트', inplace = True)
df['storetype'].replace('생선회', '해산물', inplace = True)
df['storetype'].replace('요리주점', '주류', inplace = True)
df['storetype'].replace('프랑스음식', '양식', inplace = True)
df['storetype'].replace('국수', '한식', inplace = True)
df['storetype'].replace('맥주,호프', '주류', inplace = True)
df['storetype'].replace('사철,영양탕', '한식', inplace = True)
df['storetype'].replace('칼국수,만두', '한식', inplace = True)
df['storetype'].replace('한정식', '한식', inplace = True)
df['storetype'].replace('김밥', '한식', inplace = True)
df['storetype'].replace('호떡', '카페/디저트', inplace = True)

# 한식, 양식, 일식, 중식, 퓨전, 주류, 카페/디저트, 기타 
df['storetype'].replace('종합분식', '한식', inplace = True)
df['storetype'].replace('돈가스', '양식', inplace = True)
df['storetype'].replace('소고기구이', '한식', inplace = True)
df['storetype'].replace('포장마차', '주류', inplace = True)
df['storetype'].replace('육류,고기요리', '한식', inplace = True)
df['storetype'].replace('해물,생선요리', '해산물', inplace = True)
df['storetype'].replace('돼지고기구이', '한식', inplace = True)
df['storetype'].replace('복어요리', '해산물', inplace = True)
df['storetype'].replace('차', '카페/디저트', inplace = True)
df['storetype'].replace('이자카야', '주류', inplace = True)
df['storetype'].replace('이탈리아음식', '양식', inplace = True)
df['storetype'].replace('전통,민속주점', '주류', inplace = True)
df['storetype'].replace('정육식당', '한식', inplace = True)
df['storetype'].replace('조개요리', '해산물', inplace = True)
df['storetype'].replace('장어,먹장어요리', '해산물', inplace = True)
df['storetype'].replace('족발,보쌈', '한식', inplace = True)
df['storetype'].replace('떡볶이', '기타', inplace = True)
df['storetype'].replace('치킨,닭강정', '퓨전', inplace = True)
df['storetype'].replace('닭갈비', '한식', inplace = True)
df['storetype'].replace('샌드위치', '기타', inplace = True)
df['storetype'].replace('스파게티,파스타전문', '양식', inplace = True)

# 한식, 양식, 일식, 중식, 퓨전, 주류, 카페/디저트, 해산물, 조식
df['storetype'].replace('감자탕', '한식', inplace = True)
df['storetype'].replace('초밥,롤', '일식', inplace = True)
df['storetype'].replace('만두', '중식', inplace = True)
df['storetype'].replace('빙수', '카페/디저트', inplace = True)
df['storetype'].replace('샤브샤브', '한식', inplace = True)
df['storetype'].replace('바닷가재요리', '해산물', inplace = True)
df['storetype'].replace('퓨전음식', '퓨전', inplace = True)
df['storetype'].replace('양꼬치', '중식', inplace = True)
df['storetype'].replace('주꾸미요리', '해산물', inplace = True)
df['storetype'].replace('전,빈대떡', '한식', inplace = True)
df['storetype'].replace('백숙,삼계탕', '한식', inplace = True)
df['storetype'].replace('해장국', '한식', inplace = True)
df['storetype'].replace('다이어트,샐러드', '조식', inplace = True)
df['storetype'].replace('브런치', '양식', inplace = True)
df['storetype'].replace('닭볶음탕', '한식', inplace = True)
df['storetype'].replace('아귀찜,해물찜', '해산물', inplace = True)
df['storetype'].replace('낙지요리', '해산물', inplace = True)
df['storetype'].replace('추어탕', '한식', inplace = True)
df['storetype'].replace('오뎅,꼬치', '주류', inplace = True)
df['storetype'].replace('스페인음식', '양식', inplace = True)

# 한식, 양식, 일식, 중식, 퓨전, 주류, 카페/디저트, 해산물, 조식
df['storetype'].replace('케이크전문', '카페/디저트', inplace = True)
df['storetype'].replace('피자', '양식', inplace = True)
df['storetype'].replace('국밥', '한식', inplace = True)
df['storetype'].replace('인도음식', '퓨전', inplace = True)
df['storetype'].replace('갤러리카페', '카페/디저트', inplace = True)
df['storetype'].replace('아이스크림', '카페/디저트', inplace = True)
df['storetype'].replace('향토음식', '한식', inplace = True)
df['storetype'].replace('닭발', '주류', inplace = True)
df['storetype'].replace('플라워카페', '카페/디저트', inplace = True)
df['storetype'].replace('비빔밥', '한식', inplace = True)
df['storetype'].replace('카레', '퓨전', inplace = True)
df['storetype'].replace('매운탕,해물탕', '해산물', inplace = True)
df['storetype'].replace('보리밥', '한식', inplace = True)
df['storetype'].replace('햄버거', '양식', inplace = True)
df['storetype'].replace('사찰음식', '퓨전', inplace = True)
df['storetype'].replace('찜닭', '한식', inplace = True)
df['storetype'].replace('라면', '일식', inplace = True)
df['storetype'].replace('술집', '주류', inplace = True)
df['storetype'].replace('죽', '한식', inplace = True)
df['storetype'].replace('스테이크,립', '양식', inplace = True)


# 한식, 양식, 일식, 중식, 퓨전, 주류, 카페/디저트, 해산물, 기타
df['storetype'].replace('한방카페', '카페/디저트', inplace = True)
df['storetype'].replace('도시락,컵밥', '한식', inplace = True)
df['storetype'].replace('라이브카페', '카페/디저트', inplace = True)
df['storetype'].replace('홍차전문점', '카페/디저트', inplace = True)
df['storetype'].replace('아시아음식', '퓨전', inplace = True)
df['storetype'].replace('토스트', '기타', inplace = True)
df['storetype'].replace('덮밥', '일식', inplace = True)
df['storetype'].replace('스터디카페', '카페/디저트', inplace = True)
df['storetype'].replace('북카페', '카페/디저트', inplace = True)
df['storetype'].replace('일본식라면', '일식', inplace = True)
df['storetype'].replace('굴요리', '해산물', inplace = True)
df['storetype'].replace('한식뷔페', '한식', inplace = True)
df['storetype'].replace('채식,샐러드뷔페', '', inplace = True)
df['storetype'].replace('터키음식', '퓨전', inplace = True)
df['storetype'].replace('초콜릿전문점', '카페/디저트', inplace = True)
df['storetype'].replace('패밀리레스토랑', '퓨전', inplace = True)
df['storetype'].replace('오징어요리', '해산물', inplace = True)
df['storetype'].replace('갈비탕', '한식', inplace = True)
df['storetype'].replace('주먹밥', '한식', inplace = True)
df['storetype'].replace('신의주부대찌개', '한식', inplace = True)
df['storetype'].replace('양갈비', '중식', inplace = True)
df['storetype'].replace('불닭', '한식', inplace = True)
df['storetype'].replace('일품향', '중식', inplace = True)
df['storetype'].replace('호두과자', '카페/디저트', inplace = True)
df['storetype'].replace('과일,주스전문점', '카페/디저트', inplace = True)
df['storetype'].replace('스마일찹쌀꽈배기', '카페/디저트', inplace = True)
df['storetype'].replace('갈비배달도시락스트릿테이블', '한식', inplace = True)
df['storetype'].replace('킹크랩요리', '해산물', inplace = True)
df['storetype'].replace('음식점', '한식', inplace = True)
df['storetype'].replace('아경면선', '퓨전', inplace = True)


# 한식, 양식, 일식, 중식, 퓨전, 주류, 카페/디저트, 해산물, 기타
df['storetype'].replace('오므라이스', '양식', inplace = True)
df['storetype'].replace('후렌치후라이', '양식', inplace = True)
df['storetype'].replace('일식,초밥뷔페', '일식', inplace = True)
df['storetype'].replace('고기원칙', '한식', inplace = True)
df['storetype'].replace('일점사', '한식', inplace = True)
df['storetype'].replace('마카롱', '카페/디저트', inplace = True)
df['storetype'].replace('101커피컨테이너', '카페/디저트', inplace = True)
df['storetype'].replace('대게요리', '해산물', inplace = True)
df['storetype'].replace('자연담은화로', '한식', inplace = True)
df['storetype'].replace('압구정본가불닭발', '한식', inplace = True)
df['storetype'].replace('74떡뽀끼', '기타', inplace = True)
df['storetype'].replace('달려라달봉이떡볶이', '기타', inplace = True)
df['storetype'].replace('일도씨닭갈비', '한식', inplace = True)
df['storetype'].replace('일공공키친', '한식', inplace = True)
df['storetype'].replace('스마일명품찹쌀꽈배기', '카페/디저트', inplace = True)
df['storetype'].replace('대구형제막창', '주류', inplace = True)
df['storetype'].replace('THE달달', '카페/디저트', inplace = True)
df['storetype'].replace('신가네정읍국밥', '한식', inplace = True)
df['storetype'].replace('고고즉석떡볶이', '기타', inplace = True)
df['storetype'].replace('신룽푸마라탕', '중식', inplace = True)
df['storetype'].replace('푸드트럭', '퓨전', inplace = True)
df['storetype'].replace('스파게티스토리', '양식', inplace = True)
df['storetype'].replace('문래돼지불백', '한식', inplace = True)
df['storetype'].replace('무한장어', '해산물', inplace = True)

# 한식, 양식, 일식, 중식, 퓨전, 주류, 카페/디저트, 해산물, 기타
df['storetype'].replace('72420', '퓨전', inplace = True)
df['storetype'].replace('밀겨울', '한식', inplace = True)
df['storetype'].replace('한식', '주류', inplace = True)
df['storetype'].replace('잔잔', '주류', inplace = True)
df['storetype'].replace('닭장수후라이드', '퓨전', inplace = True)
df['storetype'].replace('바나프레소', '카페/디저트', inplace = True)
df['storetype'].replace('물고기자리', '해산물', inplace = True)
df['storetype'].replace('프랜차이즈본사', '기타', inplace = True)
df['storetype'].replace('해산물뷔페', '해산물', inplace = True)
df['storetype'].replace('심야오뎅', '주류', inplace = True)
df['storetype'].replace('유흥주점', '주류', inplace = True)
df['storetype'].replace('달빛오징어광어', '해산물', inplace = True)
df['storetype'].replace('강남맥주', '주류', inplace = True)
df['storetype'].replace('가리미김밥', '한식', inplace = True)
df['storetype'].replace('미인닭발', '주류', inplace = True)
df['storetype'].replace('24시뼈다귀탕', '한식', inplace = True)
df['storetype'].replace('3일국밥', '한식', inplace = True)
df['storetype'].replace('33떡볶이', '기타', inplace = True)
df['storetype'].replace('신사골옛날감자탕', '한식', inplace = True)
df['storetype'].replace('불타는여고24시떡볶이', '기타', inplace = True)
df['storetype'].replace('일석삼조버섯매운탕', '한식', inplace = True)
df['storetype'].replace('개성진찹쌀순대', '한식', inplace = True)


# 한식, 양식, 일식, 중식, 퓨전, 주류, 카페/디저트, 해산물, 기타
df['storetype'].replace('장수한우곱창', '주류', inplace = True)
df['storetype'].replace('신떡순신천할매떡볶이', '기타', inplace = True)
df['storetype'].replace('장소대여', '기타', inplace = True)
df['storetype'].replace('반찬가게', '기타', inplace = True)
df['storetype'].replace('서오릉피자', '양식', inplace = True)
df['storetype'].replace('단란주점', '주류', inplace = True)
df['storetype'].replace('미스터떡볶이', '기타', inplace = True)
df['storetype'].replace('문배동육칼', '한식', inplace = True)
df['storetype'].replace('바른생갈비', '한식', inplace = True)
df['storetype'].replace('대게나라', '해산물', inplace = True)
df['storetype'].replace('시골한우시골돼지', '한식', inplace = True)
df['storetype'].replace('아몬드치킨', '퓨전', inplace = True)
df['storetype'].replace('감성낙곱새', '퓨전', inplace = True)
df['storetype'].replace('애플김밥', '한식', inplace = True)
df['storetype'].replace('얌얌식빵', '카페/디저트', inplace = True)
df['storetype'].replace('문어부인삼교비', '한식', inplace = True)
df['storetype'].replace('장수통닭', '퓨전', inplace = True)
df['storetype'].replace('경주빵', '카페/디저트', inplace = True)
df['storetype'].replace('미스엔불닭발', '주류', inplace = True)

# 한식, 양식, 일식, 중식, 퓨전, 주류, 카페/디저트, 해산물, 기타
df['storetype'].replace('중식당', '중식', inplace = True)
df['storetype'].replace('쌈밥', '한식', inplace = True)
df['storetype'].replace('멕시코,남미음식', '퓨전', inplace = True)
df['storetype'].replace('바(BAR)', '주류', inplace = True)
df['storetype'].replace('일식당', '일식', inplace = True)
df['storetype'].replace('냉면', '한식', inplace = True)
df['storetype'].replace('곱창,막창,양', '주류', inplace = True)
df['storetype'].replace('순대,순댓국', '한식', inplace = True)
df['storetype'].replace('베트남음식', '퓨전', inplace = True)
df['storetype'].replace('와인', '주류', inplace = True)
df['storetype'].replace('닭요리', '기타', inplace = True)
df['storetype'].replace('오리요리', '한식', inplace = True)
df['storetype'].replace('곰탕,설렁탕', '한식', inplace = True)
df['storetype'].replace('찌개,전골', '한식', inplace = True)
df['storetype'].replace('생선구이', '해산물', inplace = True)
df['storetype'].replace('분식', '기타', inplace = True)
df['storetype'].replace('조식', '기타', inplace = True)
df['storetype'].replace('테마카페', '카페/디저트', inplace = True)
df['storetype'].replace('야식', '기타', inplace = True)
df['storetype'].replace('막국수', '한식', inplace = True)
df['storetype'].replace('전복요리', '해산물', inplace = True)
df['storetype'].replace('태국음식', '퓨전', inplace = True)
df['storetype'].replace('그리스음식', '퓨전', inplace = True)
df['storetype'].replace('일식튀김,꼬치', '일식', inplace = True)
df['storetype'].replace('와플', '카페/디저트', inplace = True)
df['storetype'].replace('독일음식', '양식', inplace = True)
df['storetype'].replace('게요리', '해산물', inplace = True)
df['storetype'].replace('떡카페', '카페/디저트', inplace = True)
df['storetype'].replace('도넛', '카페/디저트', inplace = True)
df['storetype'].replace('이북음식', '퓨전', inplace = True)
df['storetype'].replace('다방', '카페/디저트', inplace = True)
df['storetype'].replace('딤섬,중식만두', '중식', inplace = True)
df['storetype'].replace('101번지남산돈까스', '양식', inplace = True)
df['storetype'].replace('안경할머니곱창', '주류', inplace = True)
df['storetype'].replace('JVL부대찌개', '한식', inplace = True)
df['storetype'].replace('기사식당', '한식', inplace = True)
df['storetype'].replace('미스터빠삭', '기타', inplace = True)
df['storetype'].replace('고레카레', '퓨전', inplace = True)
df['storetype'].replace('핫도그', '기타', inplace = True)
df['storetype'].replace('바람부리명태찜', '해산물', inplace = True)
df['storetype'].replace('신복관', '한식', inplace = True)
df['storetype'].replace('고기뷔페', '한식', inplace = True)
df['storetype'].replace('베이글', '카페/디저트', inplace = True)
df['storetype'].replace('미친노가리', '주류', inplace = True)
df['storetype'].replace('기타', '일식', inplace = True)
df['storetype'].replace('인정국물떡볶이', '기타', inplace = True)
df['storetype'].replace('달떡볶이', '기타', inplace = True)
df['storetype'].replace('일초닭발', '주류', inplace = True)
df['storetype'].replace('문스갈비', '한식', inplace = True)
df['storetype'].replace('포차세끼', '주류', inplace = True)
df['storetype'].replace('밀키트', '기타', inplace = True)
df['storetype'].replace('커피번', '카페/디저트', inplace = True)
df['storetype'].replace('크레페', '카페/디저트', inplace = True)
df['storetype'].replace('미스터세븐', '주류', inplace = True)
df['storetype'].replace('민속주점', '주류', inplace = True)
df['storetype'].replace('오니기리', '기타', inplace = True)
df['storetype'].replace('카페,디저트', '카페/디저트', inplace = True)
df['storetype'].replace('', '기타', inplace = True)


# 한식, 양식, 일식, 중식, 퓨전, 주류, 카페/디저트, 해산물, 기타

# %% [markdown]
# ### 바꾼 값의 갯수 변환을 확인해서 잘 바뀌었는지 확인

# %%
df['storetype'].unique()
# Out:
# array(['주류', '카페/디저트', '일식', '퓨전', '해산물', '양식', '중식'], dtype=object)

# %%
df.to_csv("C:/worksplaces/workspace_project/project_visual/restaurant_data/data/storetype.csv", index=None)
